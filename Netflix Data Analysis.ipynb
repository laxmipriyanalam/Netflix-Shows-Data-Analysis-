# %%
import pandas as pd
data=pd.read_csv(r'C:\Users\sanga\Downloads\archive.zip')

# %%
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# Getting some basic information about dataset

# %% [markdown]
# 1) head()

# %%
data.head()                                  #to show top-5 records of the dataset
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# 2) tail()

# %%
data.tail()                             #to show bottom-5 records of dataset
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %% [markdown]
# 3)shape

# %%
data.shape                                   #to show number of rows and columns
# Out:
# (8807, 12)

# %% [markdown]
# 4)size

# %%
data.size                         #to show total values(elements) in the dataset
# Out:
# 105684

# %% [markdown]
# 5)columns

# %%
data.columns                          #to show each column name in dataset
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# 6)dtypes

# %%
data.dtypes                         #to show the data-type of each column
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# 7)info()

# %%
data.info()                         #to show indexes,columns,data-types of each column,memory at once
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# TASK 1 : IS THERE ANY DUPLICATE RECORD IN THE DATASET? IF YES,THEN REMOVE THE DUPLICATE RECORDS.

# %% [markdown]
# duplicate()

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data.shape
# Out:
# (8807, 12)

# %%
data.duplicated()                              #to check row wise and detect the duplicate rows
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
data.drop_duplicates(inplace=True)             #to remove the duplicate rows permanently

# %%
data.shape
# Out:
# (8807, 12)

# %% [markdown]
# TASK 2 : IS THERE ANY NULL VALUE PRESENT IN ANY COLUMN ? sHOW WITH HEAT-MAP.

# %% [markdown]
# isnull()

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data.isnull()                 #to show where null value is present
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
data.isnull().sum()                  #to show the count of Null values in each column
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# Seaborn library (heat-map)

# %%
import seaborn as sns

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# Q1: For 'HOUSE OF CARDS' , What is the Show Id and whos is the director of this show ?

# %% [markdown]
# isin()

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data[data['title'].isin(['House of Cards'])]           #to show all records of particular item in any column
# Out:
#      show_id     type           title director  \
# 1059   s1060  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 1059  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           date_added  release_year rating   duration                listed_in  \
# 1059  April 14, 2021          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             description
# 1059  A ruthless politician will stop at nothing to ...

# %% [markdown]
# str.contains()

# %%
data[data['title'].str.contains('House of Cards')]           #to show all records of particular string in any column
# Out:
#      show_id     type           title director  \
# 1059   s1060  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 1059  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           date_added  release_year rating   duration                listed_in  \
# 1059  April 14, 2021          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             description
# 1059  A ruthless politician will stop at nothing to ...

# %% [markdown]
# Q2: In which year highest number of Tv shows and Movies were released ? Show with bar graph.

# %% [markdown]
# to_datetime

# %%
data['Date_N']=pd.to_datetime(data['release_year'])

# %%
data['Date_N']
# Out:
# 0      1970-01-01 00:00:00.000002020
# 1      1970-01-01 00:00:00.000002021
# 2      1970-01-01 00:00:00.000002021
# 3      1970-01-01 00:00:00.000002021
# 4      1970-01-01 00:00:00.000002021
#                     ...
# 8802   1970-01-01 00:00:00.000002007
# 8803   1970-01-01 00:00:00.000002018
# 8804   1970-01-01 00:00:00.000002009
# 8805   1970-01-01 00:00:00.000002006
# 8806   1970-01-01 00:00:00.000002015
# Name: Date_N, Length: 8807, dtype: datetime64[ns]

# %%
data['Date_N'].dt.year.value_counts()
# Out:
# Date_N
# 1970    8807
# Name: count, dtype: int64

# %% [markdown]
# Bar Graph

# %%
data['Date_N'].dt.year.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Date_N'>

# %% [markdown]
# Q3: How many Movies and TV shows are in the dataset? Show with the bar graph.

# %% [markdown]
# groupby()

# %%
data.groupby('type').type.count()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %% [markdown]
# countplot()               #to plot bar graph and is a method of seaborn library

# %%
sns.countplot(data=data, x='type')
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %% [markdown]
# Q4: Show only the titles of all TV shows that were released in India only.

# %% [markdown]
# Filtering

# %%
data[ (data['type'] == 'TV Show') & (data['country'] == 'India') ]
# Out:
#      show_id     type                               title director  \
# 4         s5  TV Show                        Kota Factory      NaN
# 39       s40  TV Show                        Chhota Bheem      NaN
# 50       s51  TV Show                       Dharmakshetra      NaN
# 66       s67  TV Show       Raja Rasoi Aur Anya Kahaniyan      NaN
# 69       s70  TV Show      Stories by Rabindranath Tagore      NaN
# ...      ...      ...                                 ...      ...
# 8173   s8174  TV Show                           Thackeray      NaN
# 8235   s8236  TV Show                         The Calling    Bumpy
# 8321   s8322  TV Show  The Golden Years with Javed Akhtar      NaN
# 8349   s8350  TV Show              The House That Made Me      NaN
# 8775   s8776  TV Show                     Yeh Meri Family      NaN
#
#                                                    cast country  \
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...   India
# ...

# %%
data[ (data['type'] == 'TV Show') & (data['country'] == 'India') ] ['title']
# Out:
# 4                             Kota Factory
# 39                            Chhota Bheem
# 50                           Dharmakshetra
# 66           Raja Rasoi Aur Anya Kahaniyan
# 69          Stories by Rabindranath Tagore
#                        ...
# 8173                             Thackeray
# 8235                           The Calling
# 8321    The Golden Years with Javed Akhtar
# 8349                The House That Made Me
# 8775                       Yeh Meri Family
# Name: title, Length: 79, dtype: object

# %% [markdown]
# Q5. Show top 10 Directors , who gave the highest number of TV Shows & Movies to Netflix ?

# %% [markdown]
# value_counts()

# %%
data['director'].value_counts()
# Out:
# director
# Rajiv Chilaka                     19
# Raúl Campos, Jan Suter            18
# Marcus Raboy                      16
# Suhas Kadav                       16
# Jay Karas                         14
#                                   ..
# Raymie Muzquiz, Stu Livingston     1
# Joe Menendez                       1
# Eric Bross                         1
# Will Eisenberg                     1
# Mozez Singh                        1
# Name: count, Length: 4528, dtype: int64

# %%
data['director'].value_counts().head(10)
# Out:
# director
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: count, dtype: int64

# %% [markdown]
# Q6: Show all the records where "Category is Movie and type is comedies" or "Country is United Kingdom" .

# %% [markdown]
# Filtering(And , Or operators)

# %%
data[(data['type']=='Movie')& (data['listed_in']=='Comedies') | (data['country']=='United Kingdom')]
# Out:
#      show_id     type                                   title  \
# 8         s9  TV Show           The Great British Baking Show
# 27       s28    Movie                               Grown Ups
# 32       s33  TV Show                           Sex Education
# 65       s66  TV Show                            Numberblocks
# 72       s73  TV Show  Jack Whitehall: Travels with My Father
# ...      ...      ...                                     ...
# 8740   s8741  TV Show                             Wild Alaska
# 8741   s8742  TV Show                             Wild Arabia
# 8744   s8745    Movie                                Williams
# 8758   s8759  TV Show                  World's Busiest Cities
# 8786   s8787    Movie                            You Can Tutu
#
#              director                                               cast  \
# 8     Andy Devonshire  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# ...

# %% [markdown]
# Q7: In how many movies/shows , Tom cruise was cast?

# %% [markdown]
# Creating new data frame

# %%
data_new=data.dropna()

# %%
data_new[data_new['cast'].str.contains('Tom Cruise')]
# Out:
#      show_id   type     title              director  \
# 341     s342  Movie  Magnolia  Paul Thomas Anderson
# 1254   s1255  Movie  Rain Man        Barry Levinson
#
#                                                    cast        country  \
# 341   John C. Reilly, Philip Baker Hall, Tom Cruise,...  United States
# 1254  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#           date_added  release_year rating duration  \
# 341   August 1, 2021          1999      R  189 min
# 1254   March 1, 2021          1988      R  134 min
#
#                        listed_in  \
# 341   Dramas, Independent Movies
# 1254      Classic Movies, Dramas
#
#                                             description  \
# 341   Through chance, history and divine interventio...
# 1254  Motivated by money, a selfish workaholic seeki...
#
#                             Date_N
# 341  1970-01-01 00:00:00.000001999
# 1254 1970-01-01 00:00:00.000001988

# %% [markdown]
# Q8: What are the different Ratings defined by Netflix ?

# %% [markdown]
# nunique()

# %%
data['rating'].nunique()
# Out:
# 17

# %% [markdown]
# unique()

# %%
data['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# Q9: How many Movies got "TV-14" rating in canada ?

# %%
data[(data['type']=='Movie') & (data['rating']=='TV-14')&(data['country']=='Canada')].shape
# Out:
# (13, 13)

# %% [markdown]
# Q10: How many TV Shows got R rating after year 2018 ?

# %%
data[(data['type']=='TV Show') & (data['rating']=='R') & (data['release_year']>2018)].shape
# Out:
# (0, 13)

# %% [markdown]
# Q11: What is the maximum duration of a Movie/Show on Netflix ?

# %%
data['duration'].unique()
# Out:
# array(['90 min', '2 Seasons', '1 Season', '91 min', '125 min',
#        '9 Seasons', '104 min', '127 min', '4 Seasons', '67 min', '94 min',
#        '5 Seasons', '161 min', '61 min', '166 min', '147 min', '103 min',
#        '97 min', '106 min', '111 min', '3 Seasons', '110 min', '105 min',
#        '96 min', '124 min', '116 min', '98 min', '23 min', '115 min',
#        '122 min', '99 min', '88 min', '100 min', '6 Seasons', '102 min',
#        '93 min', '95 min', '85 min', '83 min', '113 min', '13 min',
#        '182 min', '48 min', '145 min', '87 min', '92 min', '80 min',
#        '117 min', '128 min', '119 min', '143 min', '114 min', '118 min',
#        '108 min', '63 min', '121 min', '142 min', '154 min', '120 min',
#        '82 min', '109 min', '101 min', '86 min', '229 min', '76 min',
#        '89 min', '156 min', '112 min', '107 min', '129 min', '135 min',
#        '136 min', '165 min', '150 min', '133 min', '70 min', '84 min',
# ...

# %% [markdown]
# str.split()

# %%
data[['Minutes','Unit']]=data['duration'].str.split(' ',expand=True)

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description  \
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
#
#                          Date_N Minutes     Unit
# ...

# %% [markdown]
# max()

# %%
data['Minutes'] = pd.to_numeric(data['Minutes'], errors='coerce')
data['Minutes'].max()
# Out:
# 312.0

# %% [markdown]
# Q12: Which individual country has the highest no.of tv shows ?

# %%
data_tvshow = data[data['type']=='TV Show']

# %%
data_tvshow.head(2)
# Out:
#   show_id     type          title         director  \
# 1      s2  TV Show  Blood & Water              NaN
# 2      s3  TV Show      Ganglands  Julien Leclercq
#
#                                                 cast       country  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
#
#            date_added  release_year rating   duration  \
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
#                                          description  Minutes     Unit
# 1  After crossing paths at a party, a Cape Town t...      2.0  Seasons
# 2  To protect his family from a powerful drug lor...      1.0   Season

# %%
data_tvshow.country.value_counts()
# Out:
# country
# United States                                    760
# United Kingdom                                   213
# Japan                                            169
# South Korea                                      158
# India                                             79
#                                                 ...
# Belarus                                            1
# United Kingdom, Australia                          1
# France, Australia, Germany                         1
# Australia, New Zealand, United States              1
# United States, France, South Korea, Indonesia      1
# Name: count, Length: 196, dtype: int64

# %%
data_tvshow.country.value_counts().head(1)
# Out:
# country
# United States    760
# Name: count, dtype: int64

# %% [markdown]
# Q13: How can we sort the dataset by year ?

# %%
data.sort_values(by='release_year').head(4)
# Out:
#      show_id     type                                          title  \
# 4250   s4251  TV Show              Pioneers: First Women Filmmakers*
# 7790   s7791    Movie                                 Prelude to War
# 8205   s8206    Movie                           The Battle of Midway
# 8660   s8661    Movie  Undercover: How to Operate Behind Enemy Lines
#
#          director                       cast        country  \
# 4250          NaN                        NaN            NaN
# 7790  Frank Capra                        NaN  United States
# 8205    John Ford  Henry Fonda, Jane Darwell  United States
# 8660    John Ford                        NaN  United States
#
#              date_added  release_year rating  duration  \
# 4250  December 30, 2018          1925  TV-14  1 Season
# 7790     March 31, 2017          1942  TV-14    52 min
# 8205     March 31, 2017          1942  TV-14    18 min
# 8660     March 31, 2017          1943  TV-PG    61 min
#
# ...

# %%
data.sort_values(by='release_year',ascending=False).head(8)
# Out:
#     show_id     type                                  title         director  \
# 693    s694    Movie                 Ali & Ratu Ratu Queens   Lucky Kuswandi
# 781    s782    Movie  Black Holes | The Edge of All We Know    Peter Galison
# 762    s763    Movie                           Sweet & Sour    Lee Kae-byeok
# 763    s764  TV Show                            Sweet Tooth              NaN
# 764    s765    Movie           Trippin' with the Kandasamys    Jayan Moodley
# 765    s766    Movie                                 Xtreme  Daniel Benmayor
# 766    s767    Movie                Alan Saldaña: Locked Up        Alex Díaz
# 767    s768  TV Show                   Creator's File: GOLD              NaN
#
#                                                   cast        country  \
# 693  Iqbaal Ramadhan, Nirina Zubir, Asri Welas, Tik...            NaN
# 781                                                NaN            NaN
# ...

# %% [markdown]
# Q14: Find all the instances where category is Movie and type is dramas.

# %%
data[(data['type']=='Movie')&(data['listed_in']=='Dramas')].head(4)
# Out:
#     show_id   type               title             director  \
# 112    s113  Movie               Worth       Sara Colangelo
# 129    s130  Movie  An Unfinished Life      Lasse Hallström
# 142    s143  Movie     Freedom Writers  Richard LaGravenese
# 162    s163  Movie            Marshall      Reginald Hudlin
#
#                                                   cast  \
# 112  Michael Keaton, Stanley Tucci, Amy Ryan, Shuno...
# 129  Robert Redford, Jennifer Lopez, Morgan Freeman...
# 142  Hilary Swank, Patrick Dempsey, Scott Glenn, Im...
# 162  Chadwick Boseman, Josh Gad, Kate Hudson, Sterl...
#
#                              country         date_added  release_year rating  \
# 112                              NaN  September 3, 2021          2021  PG-13
# 129           Germany, United States  September 1, 2021          2005  PG-13
# 142           Germany, United States  September 1, 2021          2007  PG-13
# ...
